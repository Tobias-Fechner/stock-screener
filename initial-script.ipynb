# %%
from main import getSP500

# %%
import pandas as pd

# %%
stocks = getSP500(years=20)
stocks
# Out:
# WARNING: KeyError for BF.B
# WARNING: AssertionError for BRK.B
# {'A': <main.Stock at 0x20a391f2490>,
#  'AAL': <main.Stock at 0x20a4a992730>,
#  'AAP': <main.Stock at 0x20a4a992b80>,
#  'AAPL': <main.Stock at 0x20a4a992d30>,
#  'ABBV': <main.Stock at 0x20a4aa1dd00>,
#  'ABC': <main.Stock at 0x20a4aa1d4f0>,
#  'ABMD': <main.Stock at 0x20a4aa1d4c0>,
#  'ABT': <main.Stock at 0x20a4aa1db50>,
#  'ACN': <main.Stock at 0x20a4aa1d5b0>,
#  'ADBE': <main.Stock at 0x20a4aa82610>,
#  'ADI': <main.Stock at 0x20a4aa82520>,
#  'ADM': <main.Stock at 0x20a4aa82be0>,
#  'ADP': <main.Stock at 0x20a4aa82790>,
#  'ADSK': <main.Stock at 0x20a4aa82af0>,
#  'AEE': <main.Stock at 0x20a4aa825e0>,
#  'AEP': <main.Stock at 0x20a4aa82d30>,
#  'AES': <main.Stock at 0x20a4aa82f10>,
#  'AFL': <main.Stock at 0x20a4aa86910>,
#  'AIG': <main.Stock at 0x20a4aa86400>,
#  'AIV': <main.Stock at 0x20a4aa869a0>,
#  'AIZ': <main.Stock at 0x20a4aa86820>,
#  'AJG': <main.Stock at 0x20a4aa86280>,
# ...

# %%
data = stocks['ABC'].priceData.data
data
# Out:
#                   open        high         low       close    adjclose  \
# 2000-08-14    9.171875    9.234375    8.750000    8.921875    7.097373
# 2000-08-21    8.828125    9.468750    8.671875    8.703125    6.923353
# 2000-08-28    8.718750    8.906250    8.359375    8.703125    6.923353
# 2000-09-04    8.609375    8.812500    7.984375    8.546875    6.799058
# 2000-09-11    8.625000    9.718750    8.359375    9.703125    7.718863
# ...                ...         ...         ...         ...         ...
# 2020-07-13   97.279999  105.080002   96.849998  104.449997  104.022964
# 2020-07-20  104.400002  104.930000  101.680000  103.760002  103.335793
# 2020-07-27  103.379997  104.540001   98.690002  100.190002   99.780388
# 2020-08-03  100.809998  106.449997  100.529999  102.099998  101.682571
# 2020-08-10  102.260002  104.250000  101.059998  103.750000  103.325829
#
#              volume ticker
# 2000-08-14  1030800    ABC
# 2000-08-21  4494400    ABC
# 2000-08-28  5218800    ABC
# ...

# %%
data = None
df = data.iloc[-52:]
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-69af92c22fd1> in <module>
#       1 data = None
# ----> 2 df = data.iloc[-52:]
#       3 df
#
# AttributeError: 'NoneType' object has no attribute 'iloc'

# %%
min(df['low'])
# Out:
# 72.05999755859375
